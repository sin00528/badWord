# %%
import tensorflow
import numpy as np
import pandas as pd

from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib import parse
import requests

from tqdm import tqdm_notebook
import selenium

# %%
import dc_api

# %% [markdown]
# # Crawling DCinside galleries

# %%
dc_gall_list = ['baseball_new8', 'stock_new2', 'leagueoflegends3', 'etc_entertainment3' , 'ib_new1' , 'history']
df = pd.DataFrame(columns=['gall_name', 'cmt_contents'])


for gall_idx in range(len(dc_gall_list)):
    for doc, idx in tqdm_notebook(zip(dc_api.board(board_id=dc_gall_list[gall_idx]), range(1000))) :
        doc["comments"]
        for com in doc["comments"]:
            if type(com["contents"]) == str:
                data = {'gall_name': dc_gall_list[gall_idx], 'cmt_contents': com["contents"]}
                df = df.append(data, ignore_index=True)
            else:
                 continue
# Out:
# C:\Users\VI\Anaconda3\envs\badWord\lib\site-packages\ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
df = df[df['cmt_contents'] != ""]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#           gall_name                                       cmt_contents
# 0     baseball_new8                                                ㅠ.ㅠ
# 1     baseball_new8                                            댓글 지우지?
# 2     baseball_new8                                                 ㅋㅋ
# 3     baseball_new8                                   설렁설렁해라  - dc App
# 4     baseball_new8                                          Bcaa함 묵으라
# 5     baseball_new8                                               자지마라
# 6     baseball_new8                                    피부 원툴  - dc App
# 7     baseball_new8                            야리둡  후덕해졌노 ㅋㅋ  - dc App
# 8     baseball_new8                                        피부도르 수상 ㅋㅋㅋ
# 9     baseball_new8                           왜냐? 즈그 아들 딸들은 이미 졸업했기 때문
# 10    baseball_new8                           ㅇㅈ ㅋㅋㅋㅋㅋ 리얼 재앙  - dc App
# 11    baseball_new8                                  퍄퍄 — (내향성 갤러리 ㄱㄱ)
# ...

# %%
df.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)

# %%
df
# Out:
#           gall_name                                       cmt_contents
# 0     baseball_new8                                                ㅠ.ㅠ
# 1     baseball_new8                                            댓글 지우지?
# 2     baseball_new8                                                 ㅋㅋ
# 3     baseball_new8                                   설렁설렁해라  - dc App
# 4     baseball_new8                                          Bcaa함 묵으라
# 5     baseball_new8                                               자지마라
# 6     baseball_new8                                    피부 원툴  - dc App
# 7     baseball_new8                            야리둡  후덕해졌노 ㅋㅋ  - dc App
# 8     baseball_new8                                        피부도르 수상 ㅋㅋㅋ
# 9     baseball_new8                           왜냐? 즈그 아들 딸들은 이미 졸업했기 때문
# 10    baseball_new8                           ㅇㅈ ㅋㅋㅋㅋㅋ 리얼 재앙  - dc App
# 11    baseball_new8                                  퍄퍄 — (내향성 갤러리 ㄱㄱ)
# ...

# %%
df.to_csv('./data/dc_db.csv', sep=',', encoding='utf-8')

# %% [raw]
# # 갤러리 내용 확인
# for doc in dc_api.board(board_id="programming") :
#     print('======================== Divider ========================')
#     print('id : ' , doc["id"], ' title : ', doc["title"], ' author : ' ,doc["author"])
#     print('time : ', doc["time"], ' comment_num : ', doc["comment_num"], 'voteup_num : ',doc["voteup_num"])
#     print('contents :', doc["contents"])
#     doc["comments"]
#     for com in doc["comments"]:
#         print('cmt id : ', com["id"], 'cmt parent_id : ', com["parent_id"], 'cmt author : ', com["author"])
#         print('cmt time : ', com["time"])
#         if com["dccon"]:
#             print('디씨콘')
#         else:
#             print(com["contents"])
#
# # 사용방법 예시
# df = pd.DataFrame(columns=['title', 'contents', 'voteup_num'])
# for doc, idx in zip(tqdm.notebook.tqdm(dc_api.board(board_id="programming")), range(10000)) :
#     data = {'title': doc["title"], 'contents': doc['contents'], 'voteup_num': doc["voteup_num"]}
#     df = df.append(data, ignore_index=True)
#
#
# df.head()
# df.tail()
# df.sort_values(by='voteup_num', ascending=False).head(10)
